# %% [markdown]
# ## Penguins

# %% [markdown]
# <img src= https://frenzy86.s3.eu-west-2.amazonaws.com/python/penguin.png width=600 >

# %% [markdown]
# #### Columns in the dataset
# - species: penguin species (Chinstrap, Adélie, or Gentoo)
# - island: island name (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# - bill_length_mm: bill length (mm)
# - bill_length_mm: bill depth (mm)
# - flipper_length_mm: flipper length (mm)
# - body_mass_g: body mass (g)
# - Sex: penguin sex

# %% [markdown]
# <img src= https://frenzy86.s3.eu-west-2.amazonaws.com/python/penguin2.png width=600 >

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/penguins.csv
# Out:
# --2024-05-08 11:01:50--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/penguins.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 3.5.245.156, 52.95.143.30, 52.95.142.26, ...
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|3.5.245.156|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15134 (15K) [text/csv]
# Saving to: ‘penguins.csv’
#
# penguins.csv        100%[===================>]  14.78K  --.-KB/s    in 0s
#
# 2024-05-08 11:01:51 (101 MB/s) - ‘penguins.csv’ saved [15134/15134]

# %%
path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/penguins.csv"

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv(path)
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# 1           3800  female
# 2           3250  female
# 3           3450  female
# 4           3650    male
# ..           ...     ...
# 328         4000    male
# 329         3400  female
# 330         3775    male
# 331         4100    male
# 332         3775  female
#
# [333 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    int64
#  5   body_mass_g        333 non-null    int64
#  6   sex                333 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 18.3+ KB

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
#checking number of null values in the data
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df['island'].value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
df['island'].value_counts(normalize=True)
# Out:
# island
# Biscoe       0.489489
# Dream        0.369369
# Torgersen    0.141141
# Name: proportion, dtype: float64

# %%
df['species'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='species'>

# %%
df['species'].value_counts(normalize=True)
# Out:
# species
# Adelie       0.438438
# Gentoo       0.357357
# Chinstrap    0.204204
# Name: proportion, dtype: float64

# %%
sns.pairplot(df,hue='species')

# %%
corrmat = df.corr(numeric_only=True)
corrmat
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, annot = True, annot_kws={'size': 12});

# %%
sns.violinplot(data=df, x="species", y="bill_length_mm",hue="species")
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
sns.FacetGrid(df, hue="species", height=6,).map(sns.kdeplot, "body_mass_g",fill=True).add_legend()

# %%
plt.figure(figsize = [10,7])
g = sns.boxplot(x = 'island',
            y ='body_mass_g',
            hue = 'species',
            data = df,
            palette=['#FF8C00','#159090','#A034F0'],
            linewidth=0.3)
g.set_xlabel('Island')
g.set_ylabel('Body Mass')
# Out:
# Text(0, 0.5, 'Body Mass')

# %% [markdown]
# ### Advanced

# %%
sns.relplot(x="bill_length_mm", y="body_mass_g", hue="species",
                col="island", row="sex", data=df);

# %%
df = pd.get_dummies(df,columns = ['island','sex'],drop_first=True,dtype=int)
df
# Out:
#        species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0       Adelie            39.1           18.7                181         3750
# 1       Adelie            39.5           17.4                186         3800
# 2       Adelie            40.3           18.0                195         3250
# 3       Adelie            36.7           19.3                193         3450
# 4       Adelie            39.3           20.6                190         3650
# ..         ...             ...            ...                ...          ...
# 328  Chinstrap            55.8           19.8                207         4000
# 329  Chinstrap            43.5           18.1                202         3400
# 330  Chinstrap            49.6           18.2                193         3775
# 331  Chinstrap            50.8           19.0                210         4100
# 332  Chinstrap            50.2           18.7                198         3775
#
#      island_Dream  island_Torgersen  sex_male
# 0               0                 1         1
# 1               0                 1         0
# 2               0                 1         0
# 3               0                 1         0
# 4               0                 1         1
# ..            ...               ...       ...
# 328             1                 0         1
# 329             1                 0         0
# 330             1                 0         1
# 331             1                 0         1
# 332             1                 0         0
#
# [333 rows x 8 columns]

# %%
X = df.drop(columns='species')
y = df['species']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state=667
                                                    )

# %%
#Train the model with Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train) #Training the model
# Out:
# LogisticRegression()

# %%
model.intercept_ # un'intercepta per ogni classe
# Out:
# array([ 0.0253033 , -0.00754504, -0.01775826])

# %%
model.coef_ # un Beta regress per ogni variabiel di input
# Out:
# array([[-7.50888096e-01,  1.05936365e+00,  7.14933306e-02,
#          6.20249297e-04, -2.26995647e-02,  1.09556555e-01,
#          1.09257981e-01],
#        [ 1.26482858e+00,  4.46744106e-03, -1.41199863e-01,
#         -6.96389914e-03,  1.25139270e-01, -5.47892270e-02,
#          4.75768175e-03],
#        [-5.13940486e-01, -1.06383109e+00,  6.97065323e-02,
#          6.34364984e-03, -1.02439705e-01, -5.47673278e-02,
#         -1.14015663e-01]])

# %%
model.predict_proba(X_test)
# Out:
# array([[9.95860357e-01, 1.71325257e-09, 4.13964096e-03],
#        [2.49146507e-01, 7.50840317e-01, 1.31762351e-05],
#        [3.77434754e-04, 1.08151351e-05, 9.99611750e-01],
#        [9.92838777e-01, 5.77780825e-03, 1.38341492e-03],
#        [2.00683917e-03, 4.22717751e-08, 9.97993119e-01],
#        [1.95532702e-04, 3.29860209e-07, 9.99804137e-01],
#        [9.99999030e-01, 2.06212987e-08, 9.49109117e-07],
#        [3.16223636e-04, 1.17278879e-05, 9.99672048e-01],
#        [6.67441630e-01, 3.32127391e-01, 4.30979527e-04],
#        [1.10844697e-05, 9.99988838e-01, 7.73169875e-08],
#        [1.97172682e-05, 9.99980258e-01, 2.47673899e-08],
#        [9.99789526e-01, 3.34208169e-06, 2.07131778e-04],
#        [1.10034448e-03, 6.05210701e-06, 9.98893603e-01],
#        [3.66746107e-03, 4.54665187e-07, 9.96332084e-01],
#        [9.98546060e-01, 1.25329696e-03, 2.00642865e-04],
#        [7.56150656e-06, 9.99992435e-01, 3.08157500e-09],
#        [9.99178474e-01, 6.10563560e-04, 2.10962643e-04],
#        [7.69920480e-04, 5.63180269e-06, 9.99224448e-01],
#        [9.99981327e-01, 4.38968595e-08, 1.86291548e-05],
#        [6.71803077e-03, 5.11856396e-03, 9.88163405e-01],
#        [1.41445487e-04, 9.99858526e-01, 2.81045570e-08],
#        [9.99671177e-01, 2.93442196e-04, 3.53810333e-05],
#        [9.94654999e-01, 5.31467323e-03, 3.03277770e-05],
#        [1.35135462e-03, 9.98643440e-01, 5.20562964e-06],
#        [2.27749785e-04, 9.99772132e-01, 1.17883479e-07],
#        [7.55672180e-03, 7.20422219e-04, 9.91722856e-01],
#        [9.98230024e-01, 2.26188966e-08, 1.76995366e-03],
#        [9.99652444e-01, 2.88128602e-04, 5.94274013e-05],
#        [9.99932973e-01, 1.11354509e-10, 6.70271607e-05],
#        [1.57021725e-03, 1.71778805e-04, 9.98258004e-01],
#        [9.99971018e-01, 1.24937804e-05, 1.64878738e-05],
#        [9.66901195e-01, 3.30888932e-02, 9.91193108e-06],
#        [9.99852169e-01, 1.19009442e-04, 2.88212152e-05],
#        [8.53593357e-06, 9.99991462e-01, 2.48334360e-09],
#        [1.84240431e-03, 1.66453140e-04, 9.97991143e-01],
#        [1.25361542e-04, 6.10179571e-09, 9.99874632e-01],
#        [2.27017194e-04, 2.66485336e-07, 9.99772716e-01],
#        [7.33487693e-04, 7.89149164e-07, 9.99265723e-01],
#        [6.29272496e-03, 2.41679347e-04, 9.93465596e-01],
#        [1.77761548e-01, 8.21978229e-01, 2.60222709e-04],
#        [9.99970077e-01, 8.38194585e-07, 2.90846212e-05],
#        [1.32914988e-04, 7.30382654e-08, 9.99867012e-01],
#        [4.00515264e-01, 5.98602845e-01, 8.81891474e-04],
#        [1.79246392e-04, 2.07608580e-08, 9.99820733e-01],
#        [9.99954738e-01, 4.35889434e-07, 4.48259368e-05],
#        [9.92128638e-01, 4.48602835e-03, 3.38533409e-03],
#        [1.05375058e-03, 4.66235213e-04, 9.98480014e-01],
#        [5.34656434e-04, 9.99464997e-01, 3.46077936e-07],
#        [1.10725982e-03, 1.40523469e-01, 8.58369271e-01],
#        [9.99994982e-01, 5.12375954e-13, 5.01784821e-06],
#        [1.90851422e-05, 9.99980878e-01, 3.64989305e-08],
#        [9.40804949e-07, 9.99999056e-01, 3.07923592e-09],
#        [9.98253606e-01, 6.22693952e-09, 1.74638802e-03],
#        [2.65774578e-04, 2.55386297e-04, 9.99478839e-01],
#        [5.90832509e-05, 1.75481305e-08, 9.99940899e-01],
#        [9.99850496e-01, 1.45375772e-05, 1.34966014e-04],
#        [9.99991018e-01, 6.64128415e-07, 8.31815797e-06],
#        [1.32942129e-03, 7.62147555e-08, 9.98670502e-01],
#        [9.65751148e-07, 9.99999034e-01, 1.35647486e-10],
#        [9.99942166e-01, 5.15721234e-05, 6.26229068e-06],
#        [9.99559670e-01, 3.35029818e-04, 1.05300365e-04],
#        [9.60823454e-05, 7.69611195e-06, 9.99896222e-01],
#        [9.59035631e-01, 4.05748531e-02, 3.89515507e-04],
#        [2.86347349e-09, 9.99999997e-01, 1.97838585e-13],
#        [9.99991953e-01, 6.04802313e-08, 7.98654684e-06],
#        [7.97689178e-05, 2.68520422e-07, 9.99919963e-01],
#        [4.70442090e-06, 9.99995171e-01, 1.24245492e-07],
#        [2.17656475e-04, 8.69949099e-09, 9.99782335e-01],
#        [9.99804255e-01, 1.40996550e-05, 1.81645690e-04],
#        [8.92674814e-04, 3.59906670e-03, 9.95508258e-01],
#        [1.96254042e-04, 7.49587941e-03, 9.92307867e-01],
#        [2.50375903e-07, 9.99999750e-01, 3.31218902e-11],
#        [9.99829469e-01, 4.20366315e-06, 1.66327644e-04],
#        [9.99845985e-01, 2.63023696e-08, 1.53988408e-04],
#        [9.92540874e-01, 2.25385248e-07, 7.45890055e-03],
#        [5.75768122e-03, 4.34034963e-08, 9.94242275e-01],
#        [9.99636604e-01, 6.26415584e-05, 3.00754843e-04],
#        [8.66735309e-01, 1.33257289e-01, 7.40170190e-06],
#        [1.44169914e-02, 1.86381808e-06, 9.85581145e-01],
#        [1.08557013e-04, 9.99890275e-01, 1.16804437e-06],
#        [9.98590245e-01, 1.77762238e-06, 1.40797721e-03],
#        [9.99359440e-01, 9.76348885e-06, 6.30796346e-04],
#        [9.09202052e-01, 9.07810574e-02, 1.68904427e-05],
#        [1.41626104e-05, 3.93279711e-09, 9.99985833e-01]])

# %%
#Test the model
y_pred  = model.predict(X_test)
print(y_pred )# printing predictions
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie'
#  'Gentoo' 'Adelie' 'Chinstrap' 'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo'
#  'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Adelie' 'Adelie' 'Chinstrap' 'Chinstrap' 'Gentoo' 'Adelie' 'Adelie'
#  'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Chinstrap' 'Gentoo'
#  'Gentoo' 'Gentoo' 'Gentoo' 'Gentoo' 'Chinstrap' 'Adelie' 'Gentoo'
#  'Chinstrap' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Chinstrap' 'Gentoo'
#  'Adelie' 'Chinstrap' 'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie'
#  'Adelie' 'Gentoo' 'Chinstrap' 'Adelie' 'Adelie' 'Gentoo' 'Adelie'
#  'Chinstrap' 'Adelie' 'Gentoo' 'Chinstrap' 'Gentoo' 'Adelie' 'Gentoo'
#  'Gentoo' 'Chinstrap' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Adelie'
#  'Adelie' 'Gentoo' 'Chinstrap' 'Adelie' 'Adelie' 'Adelie' 'Gentoo']

# %%
confronto = pd.DataFrame(list(zip(y_pred,y_test)), columns=['predetti','reali'])
confronto
# Out:
#      predetti      reali
# 0      Adelie     Adelie
# 1   Chinstrap     Adelie
# 2      Gentoo     Gentoo
# 3      Adelie     Adelie
# 4      Gentoo     Gentoo
# ..        ...        ...
# 79  Chinstrap  Chinstrap
# 80     Adelie     Adelie
# 81     Adelie     Adelie
# 82     Adelie     Adelie
# 83     Gentoo     Gentoo
#
# [84 rows x 2 columns]

# %%
import numpy as np
length = y_pred.shape[0] # 30
x = np.linspace(0,length,length)


plt.figure(figsize=(17,6))
plt.plot(x, y_test, label='test')
plt.plot(x, y_pred, label='predetto')
plt.legend(loc=2);

# %%
X[0:1]
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0            39.1           18.7                181         3750
#
#    island_Dream  island_Torgersen  sex_male
# 0             0                 1         1

# %%
model.predict([[39.1,18.7,181,3750,0,1,1]])[0]
# Out:
# 'Adelie'

# %%
model.score(X_train,y_train)
# Out:
# 0.9879518072289156

# %%
model.score(X_test,y_test)
# Out:
# 0.9880952380952381

# %%
from sklearn.metrics import accuracy_score # è la stessa cosa model.score(X_test,y_test)

acc = accuracy_score(y_test,y_pred)
print(f"L'accuracy totale è: {round(acc,2)*100}%")
# Out:
# L'accuracy totale è: 99.0%

# %% [markdown]
# ## La cross Validation
# The performance measure reported by k-fold cross-validation is then the average of the values computed in the loop. This approach can be computationally expensive, but does not waste too much data (as is the case when fixing an arbitrary validation set), which is a major advantage in problems such as inverse inference where the number of samples is very small.

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/fav/cross_val.png" width=800 >

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X, y, cv=5)
scores
# Out:
# array([0.97014925, 0.98507463, 0.97014925, 1.        , 0.98484848])

# %%
acc_cv = np.mean(scores).round(3)
acc_cv
# Out:
# 0.982

# %%
from sklearn.metrics import confusion_matrix

#labels = y_test.sort_values().drop_duplicates().to_list()
labels = ['No Diabetics','Diabetics']

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm , square=True, annot=True, cbar=False,cmap='Blues',xticklabels=labels,yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Actual')
plt.ylabel('Prediction');

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      0.97      0.99        37
#    Chinstrap       0.94      1.00      0.97        17
#       Gentoo       1.00      1.00      1.00        30
#
#     accuracy                           0.99        84
#    macro avg       0.98      0.99      0.99        84
# weighted avg       0.99      0.99      0.99        84
